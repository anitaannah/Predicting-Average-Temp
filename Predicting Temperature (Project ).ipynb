# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# Let's read the data from the "GlobalTemperatures.csv" file, which has a monthly Earth’s temperature and plot it on the chart.

# %%
global_temp=pd.read_csv(r'C:\Users\HP\Downloads\time_series_udemy\GlobalTemperatures.csv')

# %%
global_temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
global_temp['dt'][0].split('-')[0]
# Out:
# '1750'

# %%
def fetch_year(date):
    return date.split('-')[0]

# %%
global_temp['years']=global_temp['dt'].apply(fetch_year)

# %%
global_temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty years
# 0                                        NaN  1750
# 1                                        NaN  1750
# 2                                        NaN  1750
# 3                                        NaN  1750
# 4                                        NaN  1750

# %%
data=global_temp.groupby('years').agg({'LandAverageTemperature':'mean','LandAverageTemperatureUncertainty':'mean'}).reset_index()

# %%
data
# Out:
#     years  LandAverageTemperature  LandAverageTemperatureUncertainty
# 0    1750                8.719364                           2.637818
# 1    1751                7.976143                           2.781143
# 2    1752                5.779833                           2.977000
# 3    1753                8.388083                           3.176000
# 4    1754                8.469333                           3.494250
# ..    ...                     ...                                ...
# 261  2011                9.516000                           0.082000
# 262  2012                9.507333                           0.083417
# 263  2013                9.606500                           0.097667
# 264  2014                9.570667                           0.090167
# 265  2015                9.831000                           0.092167
#
# [266 rows x 3 columns]

# %%
data['Uncertainity_top']=data['LandAverageTemperature'] + data['LandAverageTemperatureUncertainty']
data['Uncertainity_bottom']=data['LandAverageTemperature'] - data['LandAverageTemperatureUncertainty']

# %%
data.columns
# Out:
# Index(['years', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'Uncertainity_top', 'Uncertainity_bottom'],
#       dtype='object')

# %%
fig=px.line(data,x='years',y=['LandAverageTemperature','Uncertainity_top', 'Uncertainity_bottom'],title='Avg Land Temp in World')
fig.show()
# Out:
# <div>                            <div id="2bed63ef-b511-466d-b835-0335a0fd8b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bed63ef-b511-466d-b835-0335a0fd8b1e")) {                    Plotly.newPlot(                        "2bed63ef-b511-466d-b835-0335a0fd8b1e",                        [{"hovertemplate": "variable=LandAverageTemperature<br>years=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "LandAverageTemperature", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "LandAverageTemperature", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["1750", "1751", "1752", "1753", "1754", "1755", "1756", "1757", "1758", "1759", "1760", "1761", "1762", "1763", "1764", "1765", "1766", "1767", "1768", "1769", "1770", "1771", "1772", "1773", "1774", "1775", "1776", "1777", "1778", "1779", "1780", "1781", "1782", "1783", "1784", "1785", "1786", "1787", "1788", "1789", "1790", "1791", "1792", "1793", "1794", "1795", "1796", "1797", "1798", "1799", "1800", "1801", "1802", "1803", "1804", "1805", "1806", "1807", "1808", "1809", "1810", "1811", "1812", "1813", "1814", "1815", "1816", "1817", "1818", "1819", "1820", "1821", "1822", "1823", "1824", "1825", "1826", "1827", "1828", "1829", "1830", "1831", "1832", "1833", "1834", "1835", "1836", "1837", "1838", "1839", "1840", "1841", "1842", "1843", "1844", "1845", "1846", "1847", "1848", "1849", "1850", "1851", "1852", "1853", "1854", "1855", "1856", "1857", "1858", "1859", "1860", "1861", "1862", "1863", "1864", "1865", "1866", "1867", "1868", "1869", "1870", "1871", "1872", "1873", "1874", "1875", "1876", "1877", "1878", "1879", "1880", "1881", "1882", "1883", "1884", "1885", "1886", "1887", "1888", "1889", "1890", "1891", "1892", "1893", "1894", "1895", "1896", "1897", "1898", "1899", "1900", "1901", "1902", "1903", "1904", "1905", "1906", "1907", "1908", "1909", "1910", "1911", "1912", "1913", "1914", "1915", "1916", "1917", "1918", "1919", "1920", "1921", "1922", "1923", "1924", "1925", "1926", "1927", "1928", "1929", "1930", "1931", "1932", "1933", "1934", "1935", "1936", "1937", "1938", "1939", "1940", "1941", "1942", "1943", "1944", "1945", "1946", "1947", "1948", "1949", "1950", "1951", "1952", "1953", "1954", "1955", "1956", "1957", "1958", "1959", "1960", "1961", "1962", "1963", "1964", "1965", "1966", "1967", "1968", "1969", "1970", "1971", "1972", "1973", "1974", "1975", "1976", "1977", "1978", "1979", "1980", "1981", "1982", "1983", "1984", "1985", "1986", "1987", "1988", "1989", "1990", "1991", "1992", "1993", "1994", "1995", "1996", "1997", "1998", "1999", "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015"], "xaxis": "x", "y": [8.719363636363637, 7.9761428571428565, 5.7798333333333325, 8.388083333333332, 8.469333333333335, 8.355583333333334, 8.849583333333333, 9.022, 6.7435833333333335, 7.985083333333333, 7.185166666666667, 8.772499999999999, 8.606500000000002, 7.496749999999999, 8.400333333333332, 8.251916666666666, 8.405666666666667, 8.221499999999999, 6.781333333333333, 7.694583333333334, 7.691916666666667, 7.8531666666666675, 8.1935, 8.2215, 8.772166666666665, 9.183083333333334, 8.304, 8.256250000000001, 8.54225, 8.98325, 9.432916666666667, 8.102583333333332, 7.901249999999998, 7.680833333333333, 7.862000000000001, 7.3629999999999995, 8.258166666666666, 8.031833333333333, 8.447166666666668, 8.334166666666667, 7.982333333333333, 8.23425, 8.089, 8.229166666666666, 8.526000000000002, 8.350333333333333, 8.270999999999999, 8.510583333333335, 8.670250000000001, 8.505749999999999, 8.484250000000001, 8.589666666666668, 8.578166666666666, 8.503, 8.844833333333334, 8.56275, 8.434083333333332, 8.281416666666665, 7.626833333333333, 7.07 ...

# %% [markdown]
# From the charts you can see, that there is global warming nowadays. The average temperature of Earth surface has the highest value in the last three centuries. The fastest temperature growth occurred in the last 30 years! This charts also have confidence intervals, which shows that measurement of temperature has become more accurate in the last few years.

# %% [markdown]
# Analyse average temperature in each season

# %%
global_temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty years
# 0                                        NaN  1750
# 1                                        NaN  1750
# 2                                        NaN  1750
# 3                                        NaN  1750
# 4                                        NaN  1750

# %%
global_temp.dtypes
# Out:
# dt                                            object
# LandAverageTemperature                       float64
# LandAverageTemperatureUncertainty            float64
# LandMaxTemperature                           float64
# LandMaxTemperatureUncertainty                float64
# LandMinTemperature                           float64
# LandMinTemperatureUncertainty                float64
# LandAndOceanAverageTemperature               float64
# LandAndOceanAverageTemperatureUncertainty    float64
# years                                         object
# dtype: object

# %%
global_temp['dt']=pd.to_datetime(global_temp['dt'])

# %%
global_temp.dtypes
# Out:
# dt                                           datetime64[ns]
# LandAverageTemperature                              float64
# LandAverageTemperatureUncertainty                   float64
# LandMaxTemperature                                  float64
# LandMaxTemperatureUncertainty                       float64
# LandMinTemperature                                  float64
# LandMinTemperatureUncertainty                       float64
# LandAndOceanAverageTemperature                      float64
# LandAndOceanAverageTemperatureUncertainty           float64
# years                                                object
# dtype: object

# %%
global_temp['month']=global_temp['dt'].dt.month

# %%
global_temp.head()
# Out:
#           dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0 1750-01-01                   3.034                              3.574
# 1 1750-02-01                   3.083                              3.702
# 2 1750-03-01                   5.626                              3.076
# 3 1750-04-01                   8.490                              2.451
# 4 1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty years  month
# 0                                        NaN  1750      1
# 1                                        NaN  1750      2
# 2                                        NaN  1750      3
# 3                                        NaN  1750      4
# 4                                        NaN  1750      5

# %%
def get_season(month):
    if month>=3 and month<=5:
        return 'spring'
    elif month>=6 and month<=8:
        return 'summer'
    elif month>=9 and month<=11:
        return 'autumn'
    else:
        return 'winter'

# %%
global_temp['season']=global_temp['month'].apply(get_season)

# %%
global_temp.head()
# Out:
#           dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0 1750-01-01                   3.034                              3.574
# 1 1750-02-01                   3.083                              3.702
# 2 1750-03-01                   5.626                              3.076
# 3 1750-04-01                   8.490                              2.451
# 4 1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty years  month  season
# 0                                        NaN  1750      1  winter
# 1                                        NaN  1750      2  winter
# 2                                        NaN  1750      3  spring
# 3                                        NaN  1750      4  spring
# 4                                        NaN  1750      5  spring

# %%
years=global_temp['years'].unique()

# %%
spring_temps=[]
summer_temps=[]
autumn_temps=[]
winter_temps=[]

# %%
for year in years:
    current_df=global_temp[global_temp['years']==year]
    spring_temps.append(current_df[current_df['season']=='spring']['LandAverageTemperature'].mean())
    summer_temps.append(current_df[current_df['season']=='summer']['LandAverageTemperature'].mean())
    autumn_temps.append(current_df[current_df['season']=='autumn']['LandAverageTemperature'].mean())
    winter_temps.append(current_df[current_df['season']=='winter']['LandAverageTemperature'].mean())

# %%
season=pd.DataFrame()

# %%
season['year']=years
season['spring_temps']=spring_temps
season['summer_temps']=summer_temps
season['autumn_temps']=autumn_temps
season['winter_temps']=winter_temps

# %%
season.head()
# Out:
#    year  spring_temps  summer_temps  autumn_temps  winter_temps
# 0  1750      8.563000     14.518333      8.890000      2.963000
# 1  1751      6.735000     14.116000     10.673000      1.729000
# 2  1752      7.035500           NaN      7.587000      2.717000
# 3  1753      8.627333     14.608333      9.212333      1.104333
# 4  1754      9.074333     14.208333      8.957333      1.637333

# %%
season.columns
# Out:
# Index(['year', 'spring_temps', 'summer_temps', 'autumn_temps', 'winter_temps'], dtype='object')

# %%
fig=px.line(season,x='year',y=['spring_temps', 'summer_temps', 'autumn_temps', 'winter_temps'],title='Avg Temp in Each Season')
fig.show()
# Out:
# <div>                            <div id="ee3f220d-c457-4799-8982-97e33b3387e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee3f220d-c457-4799-8982-97e33b3387e5")) {                    Plotly.newPlot(                        "ee3f220d-c457-4799-8982-97e33b3387e5",                        [{"hovertemplate": "variable=spring_temps<br>year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "spring_temps", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "spring_temps", "showlegend": true, "type": "scattergl", "x": ["1750", "1751", "1752", "1753", "1754", "1755", "1756", "1757", "1758", "1759", "1760", "1761", "1762", "1763", "1764", "1765", "1766", "1767", "1768", "1769", "1770", "1771", "1772", "1773", "1774", "1775", "1776", "1777", "1778", "1779", "1780", "1781", "1782", "1783", "1784", "1785", "1786", "1787", "1788", "1789", "1790", "1791", "1792", "1793", "1794", "1795", "1796", "1797", "1798", "1799", "1800", "1801", "1802", "1803", "1804", "1805", "1806", "1807", "1808", "1809", "1810", "1811", "1812", "1813", "1814", "1815", "1816", "1817", "1818", "1819", "1820", "1821", "1822", "1823", "1824", "1825", "1826", "1827", "1828", "1829", "1830", "1831", "1832", "1833", "1834", "1835", "1836", "1837", "1838", "1839", "1840", "1841", "1842", "1843", "1844", "1845", "1846", "1847", "1848", "1849", "1850", "1851", "1852", "1853", "1854", "1855", "1856", "1857", "1858", "1859", "1860", "1861", "1862", "1863", "1864", "1865", "1866", "1867", "1868", "1869", "1870", "1871", "1872", "1873", "1874", "1875", "1876", "1877", "1878", "1879", "1880", "1881", "1882", "1883", "1884", "1885", "1886", "1887", "1888", "1889", "1890", "1891", "1892", "1893", "1894", "1895", "1896", "1897", "1898", "1899", "1900", "1901", "1902", "1903", "1904", "1905", "1906", "1907", "1908", "1909", "1910", "1911", "1912", "1913", "1914", "1915", "1916", "1917", "1918", "1919", "1920", "1921", "1922", "1923", "1924", "1925", "1926", "1927", "1928", "1929", "1930", "1931", "1932", "1933", "1934", "1935", "1936", "1937", "1938", "1939", "1940", "1941", "1942", "1943", "1944", "1945", "1946", "1947", "1948", "1949", "1950", "1951", "1952", "1953", "1954", "1955", "1956", "1957", "1958", "1959", "1960", "1961", "1962", "1963", "1964", "1965", "1966", "1967", "1968", "1969", "1970", "1971", "1972", "1973", "1974", "1975", "1976", "1977", "1978", "1979", "1980", "1981", "1982", "1983", "1984", "1985", "1986", "1987", "1988", "1989", "1990", "1991", "1992", "1993", "1994", "1995", "1996", "1997", "1998", "1999", "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015"], "xaxis": "x", "y": [8.563, 6.734999999999999, 7.035499999999999, 8.627333333333334, 9.074333333333334, 8.583666666666666, 9.466, 8.604666666666667, 6.896666666666666, 6.897333333333333, 6.653666666666666, 8.916, 7.809333333333332, 6.716, 8.192, 8.868666666666668, 8.432333333333332, 7.831, 6.144000000000001, 8.803333333333333, 7.132000000000001, 6.0523333333333325, 7.148666666666666, 8.866999999999999, 10.607, 9.036666666666667, 7.522333333333333, 7.774333333333334, 8.957999999999998, 10.370666666666667, 11.737666666666664, 7.599, 7.390999999999998, 8.397333333333334, 7.3580000000000005, 6.173666666666667, 8.849666666666666, 7.9576666666666656, 8.159333333333334, 7.783, 6.997333333333333, 7.9253333333333345, 7.914666666666666, 8.248, 9.146333333333333, 8.552, 7.507666666666666, 7.024333333333334, 8.953333333333333, 8.041666666666666, 8.224666666666666, 8.660666666666666, 7.760333333333333, 8.653666666666666, 8.863, 8.328999999999999, 8.075333333333333, 7.03, 7.066666666666666, 6.833666666666666, 6.872, 6.481999999999999, 6.191333333333333, 7.048333333333333, 6.4246666666666 ...

# %% [markdown]
# BUILDING TIME SERIES MODEL

# %%
cities=pd.read_csv(r'C:\Users\HP\Downloads\time_series_udemy\GlobalLandTemperaturesByMajorCity.csv')

# %%
cities.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
cities.shape
# Out:
# (239177, 7)

# %%
usa=cities[cities['Country']=='United States']

# %%
usa.shape
# Out:
# (8455, 7)

# %%
data=['New York','Los Angeles','San Francisco']

# %%
data2=usa[usa['City'].isin(data)]

# %%
data2.head()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 131846  1849-01-01               8.819                          2.558
# 131847  1849-02-01               9.577                          1.970
# 131848  1849-03-01              11.814                          2.173
# 131849  1849-04-01              13.704                          2.902
# 131850  1849-05-01              14.834                          2.017
#
#                City        Country Latitude Longitude
# 131846  Los Angeles  United States   34.56N   118.70W
# 131847  Los Angeles  United States   34.56N   118.70W
# 131848  Los Angeles  United States   34.56N   118.70W
# 131849  Los Angeles  United States   34.56N   118.70W
# 131850  Los Angeles  United States   34.56N   118.70W

# %%
data2=data2[['dt','AverageTemperature']]

# %%
data2.head()
# Out:
#                 dt  AverageTemperature
# 131846  1849-01-01               8.819
# 131847  1849-02-01               9.577
# 131848  1849-03-01              11.814
# 131849  1849-04-01              13.704
# 131850  1849-05-01              14.834

# %%
data2.columns=['Date','Temp']

# %%
data2.head()
# Out:
#               Date    Temp
# 131846  1849-01-01   8.819
# 131847  1849-02-01   9.577
# 131848  1849-03-01  11.814
# 131849  1849-04-01  13.704
# 131850  1849-05-01  14.834

# %%
data2.dtypes
# Out:
# Date     object
# Temp    float64
# dtype: object

# %%
data2['Date']=pd.to_datetime(data2['Date'])

# %%
data2.isna().sum()
# Out:
# Date      0
# Temp    120
# dtype: int64

# %%
data2.dropna(inplace=True)

# %%
data2.shape
# Out:
# (5096, 2)

# %%
### note: for Machine Learning,feature is a columns & we have by-default index as from 0 but for our time series Problem,we have date column our as row-index
data2.set_index('Date',inplace=True)

# %%
data2.head()
# Out:
#               Temp
# Date
# 1849-01-01   8.819
# 1849-02-01   9.577
# 1849-03-01  11.814
# 1849-04-01  13.704
# 1849-05-01  14.834

# %%
data2.tail()
# Out:
#               Temp
# Date
# 2013-05-01  15.544
# 2013-06-01  20.892
# 2013-07-01  24.722
# 2013-08-01  21.001
# 2013-09-01  17.408

# %%
plt.figure(figsize=(20,10))
import seaborn as sns
sns.lineplot(x=data2.index,y=data2['Temp'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Temp'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
#apply adfuller on data2['Temp']
test_result=adfuller(data2['Temp'])

# %% [markdown]
# #if Pvalue<0.05 ,we reject Null hypo ie alternate hypo is true,ie data is stationery
#
# #Ho: ie null hypoIt is non stationary
# #H1: ie Alternate Hypo ,It is stationary

# %%
def adfuller_test(Temp):
    result=adfuller(Temp)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
## Again test dickey fuller test on df['Sales First Difference']
adfuller_test(data2['Temp'])
# Out:
# ADF Test Statistic : -1.9989239607922018
# p-value : 0.287045104083178
# #Lags Used : 33
# Number of Observations Used : 5062
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
df=data2.copy()

# %%
df.head()
# Out:
#               Temp
# Date
# 1849-01-01   8.819
# 1849-02-01   9.577
# 1849-03-01  11.814
# 1849-04-01  13.704
# 1849-05-01  14.834

# %%
df['first_temp_diff']=df['Temp']-df['Temp'].shift(12)

# %%
df.head(20)
# Out:
#               Temp  first_temp_diff
# Date
# 1849-01-01   8.819              NaN
# 1849-02-01   9.577              NaN
# 1849-03-01  11.814              NaN
# 1849-04-01  13.704              NaN
# 1849-05-01  14.834              NaN
# 1849-06-01  21.173              NaN
# 1849-07-01  26.159              NaN
# 1849-08-01  26.099              NaN
# 1849-09-01  21.848              NaN
# 1849-10-01  16.549              NaN
# 1849-11-01  10.907              NaN
# 1849-12-01   7.032              NaN
# 1850-01-01   7.087           -1.732
# 1850-02-01   8.575           -1.002
# 1850-03-01  10.365           -1.449
# 1850-04-01  13.735            0.031
# 1850-05-01  16.633            1.799
# 1850-06-01  20.241           -0.932
# 1850-07-01  23.445           -2.714
# 1850-08-01  25.935           -0.164

# %%
adfuller_test(df['first_temp_diff'].dropna())
# Out:
# ADF Test Statistic : -16.39139368024334
# p-value : 2.6919966158173683e-29
# #Lags Used : 30
# Number of Observations Used : 5053
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df[['first_temp_diff']].plot(figsize=(30,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# EXAMINING SEASONALITY IN THE DATA

# %%
data2.head()
# Out:
#               Temp
# Date
# 1849-01-01   8.819
# 1849-02-01   9.577
# 1849-03-01  11.814
# 1849-04-01  13.704
# 1849-05-01  14.834

# %%
data2['month']=data2.index.month

# %%
data2['year']=data2.index.year

# %%
data2.head()
# Out:
#               Temp  month  year
# Date
# 1849-01-01   8.819      1  1849
# 1849-02-01   9.577      2  1849
# 1849-03-01  11.814      3  1849
# 1849-04-01  13.704      4  1849
# 1849-05-01  14.834      5  1849

# %%
pivot=data2.pivot_table(values='Temp',index='month',columns='year')

# %%
pivot
# Out:
# year    1743    1744   1745    1750    1751   1752    1753    1754    1755  \
# month
# 1        NaN     NaN -2.363  -4.310  -3.591 -7.588  -3.122  -2.252  -3.193
# 2        NaN     NaN -2.671  -2.719  -2.051    NaN  -1.467  -2.583  -1.802
# 3        NaN     NaN  1.363   2.773   3.256  3.322   4.207   2.728   1.112
# 4        NaN   9.788  8.209   8.848   7.992  7.402   8.099     NaN   8.714
# 5        NaN  15.708    NaN  15.411     NaN    NaN  15.330     NaN  15.238
# 6        NaN  21.210    NaN  19.017  20.724    NaN  20.820  20.075  19.964
# 7        NaN  22.207    NaN  24.203  22.668    NaN  22.524  22.503     NaN
# 8        NaN     NaN    NaN  22.135  21.547    NaN  21.324  21.461     NaN
# 9        NaN  14.922    NaN  17.445  15.812    NaN  15.548  16.281  16.137
# 10       NaN   8.968    NaN   9.076     NaN  9.391  10.479  11.477   8.669
# 11     3.264   3.161    NaN     NaN     NaN  5.831   3.363     NaN   3.599
# 12       NaN  -2.681    NaN  -1.093     NaN -1.471  -2.854  -0.752  -2.381
#
# year     1756  ...     2004     2005     2006     2007     2008     2009  \
# month          ...
# 1      -1.985  ...   1.6315   3.1295   5.7270   4.4015   3.8115   3.2610
# 2       0.259  ...   3.8995   5.0000   5.6110   3.0920   4.9070   4.6315
# 3         NaN  ...  10.3695   6.8465   6.3190   8.8780   8.4680   7.7875
# 4         NaN  ...  12.9185  12.1785  11.5305  11.4545  12.9355  12.2230
# 5         NaN  ...  18.3025  15.6575  17.1110  17.3920  15.3875  17.7410
# 6      20.488  ...  20.4685  20.7930  22.0205  21.3570  22.4755  19.1825
# 7      22.452  ...  23.2300  24.6900  25.7505  23.7800  24.3625  23.4100
# 8      21.208  ...  22.8605  24.3255  23.0850  23.7345  23.0595  23.5765
# 9      17.345  ...  20.7435  20.2015  19.5735  19.9480  21.0230  20.6540
# 10      9.662  ...  13.4700  14.5085  13.6220  16.2585  14.8730  13.5010
# 11      2.894  ...   8.8505  10.8020  11.5525   9.6155  10.2280  10.9975
# 12     -2.900  ...   4.9095   4.5445   6.9515   4.0520   4.4075   3.9475
#
# year      2010     2011     2012     2013
# month
# 1       3.8655   2.9845   5.7700   3.9225
# 2       4.4485   3.7575   6.3970   4.2195
# 3       9.5760   7.7295  10.1550   8.4905
# 4      12.1795  12.3860  12.5375  12.8220
# 5      16.5070  16.3230  18.2280  17.2860
# 6      21.3335  20.1855  20.6155  21.6630
# 7      24.2125  24.2755  24.1650  24.9060
# 8      23.1075  23.3485  24.8115  22.6165
# 9      20.7960  21.0145  21.4610  20.3545
# 10     14.4105  15.1225  15.5740      NaN
# 11      8.9950   9.8280   9.0030      NaN
# 12      4.0360   5.9275   5.6490      NaN
#
# [12 rows x 266 columns]

# %%
pivot.plot(figsize=(20,6))
plt.legend().remove()
plt.xlabel('Months')
plt.ylabel('Temperatures')

# %% [markdown]
# INTERPRETATION :looking this graph,we can say this data is seasonal The series clearly has some seasonality, the higher temperatures are around b/w June & August and the lower are between December & Feb so thats basically a observation that u can drawn and represent to ur client.

# %%
monthly_seasonality=pivot.mean(axis=1)

# %%
monthly_seasonality.plot(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.head()
# Out:
#               Temp  first_temp_diff
# Date
# 1849-01-01   8.819              NaN
# 1849-02-01   9.577              NaN
# 1849-03-01  11.814              NaN
# 1849-04-01  13.704              NaN
# 1849-05-01  14.834              NaN

# %%
df=df[['first_temp_diff']]

# %%
df.head()
# Out:
#             first_temp_diff
# Date
# 1849-01-01              NaN
# 1849-02-01              NaN
# 1849-03-01              NaN
# 1849-04-01              NaN
# 1849-05-01              NaN

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#             first_temp_diff
# Date
# 1850-01-01           -1.732
# 1850-02-01           -1.002
# 1850-03-01           -1.449
# 1850-04-01            0.031
# 1850-05-01            1.799

# %%
### smoothening your Time Series data

# %%
df['first_temp_diff'].rolling(window=5).mean()
# Out:
# Date
# 1850-01-01       NaN
# 1850-02-01       NaN
# 1850-03-01       NaN
# 1850-04-01       NaN
# 1850-05-01   -0.4706
#                ...
# 2013-05-01   -2.7058
# 2013-06-01   -2.3750
# 2013-07-01   -1.6164
# 2013-08-01   -0.7192
# 2013-09-01   -0.7528
# Name: first_temp_diff, Length: 5084, dtype: float64

# %%
value=pd.DataFrame(df['first_temp_diff'])

# %%
temp_df=pd.concat([value,df['first_temp_diff'].rolling(window=5).mean()],axis=1)

# %%
temp_df.columns=['actual_temp','forecast_temp']

# %%
temp_df.head(20)
# Out:
#             actual_temp  forecast_temp
# Date
# 1850-01-01       -1.732            NaN
# 1850-02-01       -1.002            NaN
# 1850-03-01       -1.449            NaN
# 1850-04-01        0.031            NaN
# 1850-05-01        1.799        -0.4706
# 1850-06-01       -0.932        -0.3106
# 1850-07-01       -2.714        -0.6530
# 1850-08-01       -0.164        -0.3960
# 1850-09-01        0.714        -0.2594
# 1850-10-01        1.028        -0.4136
# 1850-11-01        0.024        -0.2224
# 1850-12-01       -0.779         0.1646
# 1851-01-01        0.462         0.2898
# 1851-02-01       -0.498         0.0474
# 1851-03-01        0.658        -0.0266
# 1851-04-01        0.895         0.1476
# 1851-05-01        0.111         0.3256
# 1851-06-01        1.265         0.4862
# 1851-07-01        0.136         0.6130
# 1851-08-01       -1.049         0.2716

# %%
from sklearn.metrics import mean_squared_error

# %%
### then check accuracy
np.sqrt(mean_squared_error(temp_df['forecast_temp'][4:],temp_df['actual_temp'][4:]))
# Out:
# 2.683706256811724

# %% [markdown]
# IMPLEMENTING ARIMA MODEL

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
df.head()
# Out:
#             first_temp_diff
# Date
# 1850-01-01           -1.732
# 1850-02-01           -1.002
# 1850-03-01           -1.449
# 1850-04-01            0.031
# 1850-05-01            1.799

# %%
plot_acf(df['first_temp_diff'].dropna())

# %%
plot_pacf(df['first_temp_diff'].dropna())

# %%
df.isna().sum()
# Out:
# first_temp_diff    0
# dtype: int64

# %%
df.shape
# Out:
# (5084, 1)

# %%
training_data=df[0:4000]
### create test that is basically unseen to our model, or which is basocally is used for evalaution
test_data=df[4000:]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
arima=ARIMA(training_data,order=(2,1,3))

# %%
model=arima.fit()

# %%
predictions=model.forecast(steps=len(test_data))[0]

# %%
np.sqrt(mean_squared_error(test_data,predictions))
# Out:
# 2.272298036786808

# %% [markdown]
# Model Tuning or Hyperparameter Tuning or choosing the best pair of (p,d,q)

# %%
p_values=range(0,4)
q_values=range(0,4)
d_values=range(0,3)

# %%
for p in p_values:
    for d in d_values:
        for q in q_values:
            order=(p,d,q)
            train=df[0:4000]
            test=df[4000:]
            predictions=[]
            for i in range(len(test)):
                try:
                    arima=ARIMA(train,order)
                    model=arima.fit(disp=0)
                    pred=model.forecast()[0]
                    predictions.append(pred)
                    error=mean_squared_error(test,predictions)
                    print('MSE is {} with order {}'.format(error,order))
                except:
                    continue
# Out:
# MSE is 5.151447647854095 with order (0, 0, 0)
# MSE is 6.153467570813493 with order (0, 0, 1)
# MSE is 6.506014778530486 with order (0, 0, 2)
